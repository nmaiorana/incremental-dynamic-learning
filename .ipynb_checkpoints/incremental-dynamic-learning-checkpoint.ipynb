# %% [markdown]
# # Incremental Dynamic Learning
#
# ## Overview
#
# The idea behind Incremental Dynamic Learning networks is that information is not always learned at once, up front. As information is encountered, we train on the new data. Adding the new information to our existing knowlege base. Humans, are said to be able to recognize an image in 13 milliseconds after seeing it.The new image is added to their existing learned information and they do not have to retrain on all images they have ever seen.
#
# ## Example
#
# As an example of how this can be used in the real world, I will use field biologists for my use case.
#
# Imagine a group of field biologists are in the field and all have a mobile application which allows them to photograph wildlife they encounter, label it and forward it to a central system. The central system takes in the new photographs and trains a neural network on each piece of new data that comes in. W/out having to retrain a new model based on all past photographs.

# %% [markdown]
# ## Experiment 1
#
# The experiment will consist of using a pre-trained network from TensorFlow (VGG) to generate our classification data. Our data will consist of using flower images provided with TensorFlow examples.
#
# Once the data has be converted by the VGG network, the process of training our network begins. This will be done by feeding the network 1 image at a time, allowing the network to train for a short duration (13ms) and then move onto the next image. A fixed validation set will be used to monitor progress as the images are fed one at a time to the network.
#
# The goal is to get an acceptable accuracy, similar to what a traditionally trained network would achieve.

# %% [markdown]
# ## Experment 2
#
# For the second half of this experiment will be to start with a single classification item 'UNKNOWN' and grow the classification set as needed. This will be done by checking a classificaiton index dictionary for the incoming label. If the label does not exist, then a prediction will be made with the current network. The classifcation that matches the image the best will be used to prime the initial weights of the new node to be added to the classifcation set. Once the node is added, the normal training on the image will be performed.

# %% [markdown]
# ## Structure
#
# The base for this experiment will be from a lesson given by Udacity on Transfer Learning. The first part of this lesson uses VGG to generate the training data for a flower classifcation system. I will use the output from that lesson to provide the training for this Expermiment.

# %% [markdown]
# ## Get libraries and data

# %%
import os

import numpy as np
import tensorflow as tf

# %%
# read codes and labels from file
import csv

with open('labels') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader if len(each) > 0]).squeeze()
with open('codes') as f:
    codes = np.fromfile(f, dtype=np.float32)
    codes = codes.reshape((len(labels), -1))

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
lb.fit(labels)

labels_vecs = lb.transform(labels)

# %%
from sklearn.model_selection import  train_test_split

X_train, X_test, y_train, y_test = train_test_split(codes, labels_vecs, train_size=0.8, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %%
print("Train shapes (x, y):", X_train.shape, y_train.shape)
print("Validation shapes (x, y):", X_val.shape, y_val.shape)
print("Test shapes (x, y):", X_test.shape, y_test.shape)
# Out:
# Train shapes (x, y): (2642, 4096) (2642, 5)
# Validation shapes (x, y): (294, 4096) (294, 5)
# Test shapes (x, y): (734, 4096) (734, 5)

# %% [markdown]
# ## Construct the network

# %%
from tensorflow.contrib.keras import models
from tensorflow.contrib.keras import layers
from tensorflow.contrib.keras import optimizers

def build_flower_classifcation_model(learning_rate=0.001):

    # Power ball powerball numbers model
    model = models.Sequential()
    model.add(layers.Dense(256, input_shape=[codes.shape[1]]))
    model.add(layers.Dense(labels_vecs.shape[1], 
                           kernel_initializer='zeros', 
                           bias_initializer='zeros'))

    model.add(layers.Activation('softmax', name='out'))
    optimizer = optimizers.Adam(lr=learning_rate)

    model.compile(optimizer=optimizer,
                  loss='mean_squared_error',
                  metrics=['accuracy'])
    model.summary()
    return model

# %%
model = build_flower_classifcation_model(learning_rate=0.0001)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 256)               1048832
# _________________________________________________________________
# dense_31 (Dense)             (None, 5)                 1285
# _________________________________________________________________
# out (Activation)             (None, 5)                 0
# =================================================================
# Total params: 1,050,117
# Trainable params: 1,050,117
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model 1 image at a time

# %%
for index in range(len(X_train)):
    single_image = X_train[index:index+1]
    single_label = y_train[index:index+1]
    if index % 10 == 0:
        verbose = True
    else:
        verbose = False
    
    print ('Image: ', index)
    model.fit(single_image, single_label, validation_data=(X_val, y_val), batch_size=1, epochs=2, verbose=verbose)
    
print (model.evaluate(X_test, y_test))
# Out:
# Image:  0
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.1600 - acc: 0.0000e+00 - val_loss: 0.1604 - val_acc: 0.1395
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1474 - acc: 1.0000 - val_loss: 0.1612 - val_acc: 0.1395
# Image:  1
# Image:  2
# Image:  3
# Image:  4
# Image:  5
# Image:  6
# Image:  7
# Image:  8
# Image:  9
# Image:  10
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.1433 - acc: 1.0000 - val_loss: 0.1479 - val_acc: 0.4286
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1403 - acc: 1.0000 - val_loss: 0.1472 - val_acc: 0.4116
# Image:  11
# Image:  12
# Image:  13
# Image:  14
# Image:  15
# Image:  16
# Image:  17
# Image:  18
# Image:  19
# Image:  20
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.1804 - acc: 0.0000e+00 - val_loss: 0.1349 - val_acc: 0.4320
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1786 - acc: 0.0000e+00 - val_loss: 0.1343 - val_acc: 0.4320
# Image:  21
# Image:  22
# Image:  23
# Image:  24
# Image:  25
# Image:  26
# Image:  27
# Image:  28
# Image:  29
# Image:  30
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.1157 - acc: 0.0000e+00 - val_loss: 0.1239 - val_acc: 0.5782
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1110 - acc: 1.0000 - val_loss: 0.1233 - val_acc: 0.5544
# Image:  31
# Image:  32
# Image:  33
# Image:  34
# Image:  35
# Image:  36
# Image:  37
# Image:  38
# Image:  39
# Image:  40
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.1724 - acc: 0.0000e+00 - val_loss: 0.1156 - val_acc: 0.6020
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1680 - acc: 0.0000e+00 - val_loss: 0.1152 - val_acc: 0.6054
# Image:  41
# Image:  42
# Image:  43
# Image:  44
# Image:  45
# Image:  46
# Image:  47
# Image:  48
# Image:  49
# Image:  50
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.0197 - acc: 1.0000 - val_loss: 0.1171 - val_acc: 0.5306
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.0178 - acc: 1.0000 - val_loss: 0.1168 - val_acc: 0.5340
# Image:  51
# Image:  52
# Image:  53
# Image:  54
# Image:  55
# Image:  56
# Image:  57
# Image:  58
# Image:  59
# Image:  60
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.0103 - acc: 1.0000 - val_loss: 0.1105 - val_acc: 0.5136
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.0076 - acc: 1.0000 - val_loss: 0.1109 - val_acc: 0.5102
# Image:  61
# Image:  62
# Image:  63
# Image:  64
# Image:  65
# Image:  66
# Image:  67
# Image:  68
# Image:  69
# Image:  70
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.0060 - acc: 1.0000 - val_loss: 0.0938 - val_acc: 0.6054
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.0063 - acc: 1.0000 - val_loss: 0.0925 - val_acc: 0.6156
# Image:  71
# Image:  72
# Image:  73
# Image:  74
# Image:  75
# Image:  76
# Image:  77
# Image:  78
# Image:  79
# Image:  80
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.1946 - acc: 0.0000e+00 - val_loss: 0.0900 - val_acc: 0.6769
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1540 - acc: 0.0000e+00 - val_loss: 0.0915 - val_acc: 0.6565
# Image:  81
# Image:  82
# Image:  83
# Image:  84
# Image:  85
# Image:  86
# Image:  87
# Image:  88
# Image:  89
# Image:  90
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.2007 - acc: 0.0000e+00 - val_loss: 0.0929 - val_acc: 0.6463
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1805 - acc: 0.0000e+00 - val_loss: 0.0904 - val_acc: 0.6463
# Image:  91
# Image:  92
# Image:  93
# Image:  94
# Image:  95
# Image:  96
# Image:  97
# Image:  98
# Image:  99
# Image:  100
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.1263 - acc: 0.0000e+00 - val_loss: 0.0965 - val_acc: 0.6190
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1243 - acc: 0.0000e+00 - val_loss: 0.0976 - val_acc: 0.6156
# Image:  101
# Image:  102
# Image:  103
# Image:  104
# Image:  105
# Image:  106
# Image:  107
# Image:  108
# Image:  109
# Image:  110
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.0255 - acc: 1.0000 - val_loss: 0.0636 - val_acc: 0.7721
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.0233 - acc: 1.0000 - val_loss: 0.0633 - val_acc: 0.7755
# Image:  111
# Image:  112
# Image:  113
# Image:  114
# Image:  115
# Image:  116
# Image:  117
# Image:  118
# Image:  119
# Image:  120
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 4.3820e-04 - acc: 1.0000 - val_loss: 0.0637 - val_acc: 0.7653
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 3.8372e-04 - acc: 1.0000 - val_loss: 0.0639 - val_acc: 0.7619
# Image:  121
# Image:  122
# Image:  123
# Image:  124
# Image:  125
# Image:  126
# Image:  127
# Image:  128
# Image:  129
# Image:  130
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.1816 - acc: 0.0000e+00 - val_loss: 0.0640 - val_acc: 0.7687
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1542 - acc: 0.0000e+00 - val_loss: 0.0657 - val_acc: 0.7653
# Image:  131
# Image:  132
# Image:  133
# Image:  134
# Image:  135
# Image:  136
# Image:  137
# Image:  138
# Image:  139
# Image:  140
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.1728 - acc: 0.0000e+00 - val_loss: 0.0726 - val_acc: 0.7381
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.1575 - acc: 0.0000e+00 - val_loss: 0.0735 - val_acc: 0.7313
# Image:  141
# Image:  142
# Image:  143
# Image:  144
# Image:  145
# Image:  146
# Image:  147
# Image:  148
# Image:  149
# Image:  150
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.0183 - acc: 1.0000 - val_loss: 0.0923 - val_acc: 0.6531
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.0066 - acc: 1.0000 - val_loss: 0.0964 - val_acc: 0.6361
# Image:  151
# Image:  152
# Image:  153
# Image:  154
# Image:  155
# Image:  156
# Image:  157
# Image:  158
# Image:  159
# Image:  160
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.3177 - acc: 0.0000e+00 - val_loss: 0.0873 - val_acc: 0.6599
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.2935 - acc: 0.0000e+00 - val_loss: 0.0845 - val_acc: 0.6633
# Image:  161
# Image:  162
# Image:  163
# Image:  164
# Image:  165
# Image:  166
# Image:  167
# Image:  168
# Image:  169
# Image:  170
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.3041 - acc: 0.0000e+00 - val_loss: 0.0620 - val_acc: 0.7415
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.2875 - acc: 0.0000e+00 - val_loss: 0.0606 - val_acc: 0.7415
# Image:  171
# Image:  172
# Image:  173
# Image:  174
# Image:  175
# Image:  176
# Image:  177
# Image:  178
# Image:  179
# Image:  180
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.2705 - acc: 0.0000e+00 - val_loss: 0.0579 - val_acc: 0.7857
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.2162 - acc: 0.0000e+00 - val_loss: 0.0583 - val_acc: 0.7823
# Image:  181
# Image:  182
# Image:  183
# Image:  184
# Image:  185
# Image:  186
# Image:  187
# Image:  188
# Image:  189
# Image:  190
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0734 - val_acc: 0.7415
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0738 - val_acc: 0.7449
# Image:  191
# Image:  192
# Image:  193
# Image:  194
# Image:  195
# Image:  196
# Image:  197
# Image:  198
# Image:  199
# Image:  200
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.2550 - acc: 0.0000e+00 - val_loss: 0.0749 - val_acc: 0.7313
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.2537 - acc: 0.0000e+00 - val_loss: 0.0744 - val_acc: 0.7313
# Image:  201
# Image:  202
# Image:  203
# Image:  204
# Image:  205
# Image:  206
# Image:  207
# Image:  208
# Image:  209
# Image:  210
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 0.0424 - acc: 1.0000 - val_loss: 0.0638 - val_acc: 0.7721
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 0.0370 - acc: 1.0000 - val_loss: 0.0629 - val_acc: 0.7721
# Image:  211
# Image:  212
# Image:  213
# Image:  214
# Image:  215
# Image:  216
# Image:  217
# Image:  218
# Image:  219
# Image:  220
# Train on 1 samples, validate on 294 samples
# Epoch 1/2
# 1/1 [==============================] - 0s - loss: 3.8093e-08 - acc: 1.0000 - val_loss: 0.0646 - val_acc: 0.7585
# Epoch 2/2
# 1/1 [==============================] - 0s - loss: 4.1213e-08 - acc: 1.0000 - val_loss: 0.0654 - val_acc: 0.7585
# Image:  221
# Image:  222
# Image:  223
# Image:  224
